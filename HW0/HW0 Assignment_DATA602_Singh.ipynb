# %% [markdown]
# This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.
#
# The goal is to write a function to count the frequency of different characters in a given string. For example: character_frequency('google') should return a `dict`: {'g': 2, 'o': 2, 'l': 1, 'e': 1}.
#
# There are many tutorials on the web that can show you how to use the Python data structures. Quite a few examples at: https://docs.python.org/3/tutorial/datastructures.html
#
#
# You should edit the function definition below, make sure to press 'Shift + Enter' to execute it, and then execute the two function calls to check that the output is correct.

# %%
def character_frequency(s):
    ret = {}
    for i in s:
        if i in ret:
            ret[i]+=1
        else:
            ret[i]=1
    return ret

# %%
character_frequency('google')
# Out:
# {'g': 2, 'o': 2, 'l': 1, 'e': 1}

# %%
character_frequency('This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.')
# Out:
# {'T': 1,
#  'h': 2,
#  'i': 6,
#  's': 7,
#  ' ': 15,
#  'a': 5,
#  'g': 1,
#  'n': 6,
#  'm': 2,
#  'e': 10,
#  't': 10,
#  'd': 4,
#  'o': 6,
#  'u': 4,
#  'r': 3,
#  'y': 2,
#  'b': 3,
#  'l': 1,
#  'J': 1,
#  'p': 1,
#  'N': 1,
#  'k': 1,
#  '.': 1}

# %% [markdown]
# In Below, Provide GitHub Repository URL:

# %% [markdown]
# https://github.com/Ritik294/DATA602_FardinaAlam

# %% [markdown]
# In Below, GitHub Page URL:

# %% [markdown]
# https://ritik294.github.io/DATA602_FardinaAlam/

# %% [markdown]
# In Below, Python and Jupyter Notebook Screenshots

# %% [markdown]
# ![Screenshot 2024-08-30 185018.png](attachment:c0b7af51-0bf8-47fb-b778-bd8569ecb8b6.png)

# %% [markdown]
# ![Screenshot 2024-08-30 184432.png](attachment:56465427-88a3-47eb-bea6-2303c5d00d09.png)

# %% [markdown]
# In Below, Google Colab Screenshot:

# %% [markdown]
# ![Screenshot 2024-08-30 183853.png](attachment:83485b2f-2bfe-4cf9-97db-3063ca8b642a.png)

# %% [markdown]
# In Below, PyTorch Screenshot:

# %% [markdown]
# ![Screenshot 2024-08-30 184604.png](attachment:3a6411eb-bfd5-4979-bc1a-fc5ae629b5d9.png)

# %% [markdown]
# In Below, Bonus Task Docker screenshots:

# %% [markdown]
# ![Screenshot 2024-08-30 184719.png](attachment:da9dd9cd-ec9f-425d-be4d-3cb6eb76f754.png)

# %% [markdown]
# ![Screenshot 2024-08-30 184820.png](attachment:1aec669e-9f78-411a-92e9-27834ba6558e.png)
